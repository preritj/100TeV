# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from ROOT import TFile, TTree, TH1F, TH2F, TChain, TCanvas, kRed, gStyle, gROOT, gPad
#from ROOT import gROOT, TCanvas, TF1, TFile, TTree, gRandom, TH1F
from utils import rootnotes
from utils import rootprint
import numpy as np
import os
# Out:
# Welcome to ROOTaaS 6.06/02

# %% [markdown]
# # Fraction of energy in a jet carried by charged particles (tracks)
# ## Using my own tt sample :

# %%
inputFile = TFile("/Users/prerit/Physics/100TeV/Stops/Results/tt/test/combined.root")
tree = inputFile.Get("event")
c=rootnotes.canvas()
tree.Draw("Top_RatioTrk[0]","cWeight")
c
# Out:
# <ROOT.TCanvas object ("icanvas") at 0x11ceb4f70>
# Info in <TCanvas::Print>: png file /var/folders/_r/z89y9x9j7cv8h_9n9l58gd8c0000gn/T/tmpUibSGw.png has been created

# %% [markdown]
# ## Using snowmass tt sample :

# %%
inputFile = TFile("/Users/prerit/Physics/100TeV/Stops/Results/tt/combined.root")
tree = inputFile.Get("event")
c=rootnotes.canvas()
tree.Draw("Top_RatioTrk[0]","cWeight")
c
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: icanvas
# <ROOT.TCanvas object ("icanvas") at 0x11cead3f0>
# Info in <TCanvas::Print>: png file /var/folders/_r/z89y9x9j7cv8h_9n9l58gd8c0000gn/T/tmpIDPOHW.png has been created
